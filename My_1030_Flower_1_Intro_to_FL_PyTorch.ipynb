# %% [markdown]
# ## Step 0: Preparation
#
# Before we begin with any actual code, let's make sure that we have everything we need.
#
#
#
# 1.   Dependencies(In Colab you could either import your dependencies or you always have to re-execute them once your runtime is stopped). We could use Jupyter-Notebook if you are considering to run in your own local machine.
# 2.   Packages (torch, numpy, matplotlib, flwr, etc.)
# 3.   Datasets (In this simulation we use CIFAR 10)

# %% [markdown]
# ### Installing dependencies
#
# Next, we install the necessary packages for PyTorch (`torch` and `torchvision`) and Flower (`flwr`):

# %%
# !pip install -q flwr[simulation] torch torchvision matplotlib

# %% [markdown]
# Now that we have all dependencies installed, we can import everything we need for this tutorial:

# %%
from collections import OrderedDict
from typing import List, Tuple

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import CIFAR10

import flwr as fl
from flwr.common import Metrics

DEVICE = torch.device("cpu")  # Try "cuda" to train on GPU
print(
    f"Training on {DEVICE} using PyTorch {torch.__version__} and Flower {fl.__version__}"
)
# Out:
# Training on cpu using PyTorch 2.1.0+cu118 and Flower 1.5.0

# %% [markdown]
# It is possible to switch to a runtime that has GPU acceleration enabled (on Google Colab: `Runtime > Change runtime type > Hardware acclerator: GPU > Save`). Note, however, that Google Colab is not always able to offer GPU acceleration. If you see an error related to GPU availability in one of the following sections, consider switching back to CPU-based execution by setting `DEVICE = torch.device("cpu")`. If the runtime has GPU acceleration enabled, you should see the output `Training on cuda`, otherwise it'll say `Training on cpu`.

# %% [markdown]
# ### Loading the data
#
# Federated learning can be applied to many different types of tasks across different domains. In this tutorial, we introduce federated learning by training a simple convolutional neural network (CNN) on the popular CIFAR-10 dataset. CIFAR-10 can be used to train image classifiers that distinguish between images from ten different classes:

# %%
CLASSES = (
    "plane",
    "car",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
)

# %% [markdown]
# We simulate having multiple datasets from multiple organizations (also called the "cross-silo" setting in federated learning) by splitting the original CIFAR-10 dataset into multiple partitions. Each partition will represent the data from a single organization. We're doing this purely for experimentation purposes, in the real world there's no need for data splitting because each organization already has their own data (so the data is naturally partitioned).
#
# Each organization will act as a client in the federated learning system. So having ten organizations participate in a federation means having ten clients connected to the federated learning server:

# %%
NUM_CLIENTS = 10

# %% [markdown]
# Let's now load the CIFAR-10 training and test set, partition them into ten smaller datasets (each split into training and validation set), and wrap the resulting partitions by creating a PyTorch `DataLoader` for each of them:

# %%
BATCH_SIZE = 32


def load_datasets():
    # Download and transform CIFAR-10 (train and test)
    transform = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
    )
    trainset = CIFAR10("./dataset", train=True, download=True, transform=transform)
    testset = CIFAR10("./dataset", train=False, download=True, transform=transform)

    # Split training set into 10 partitions to simulate the individual dataset
    partition_size = len(trainset) // NUM_CLIENTS
    lengths = [partition_size] * NUM_CLIENTS
    datasets = random_split(trainset, lengths, torch.Generator().manual_seed(42))

    # Split each partition into train/val and create DataLoader
    trainloaders = []
    valloaders = []
    for ds in datasets:
        len_val = len(ds) // 10  # 10 % validation set
        len_train = len(ds) - len_val
        lengths = [len_train, len_val]
        ds_train, ds_val = random_split(ds, lengths, torch.Generator().manual_seed(42))
        trainloaders.append(DataLoader(ds_train, batch_size=BATCH_SIZE, shuffle=True))
        valloaders.append(DataLoader(ds_val, batch_size=BATCH_SIZE))
    testloader = DataLoader(testset, batch_size=BATCH_SIZE)
    return trainloaders, valloaders, testloader


trainloaders, valloaders, testloader = load_datasets()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# We now have a list of ten training sets and ten validation sets (`trainloaders` and `valloaders`) representing the data of ten different organizations. Each `trainloader`/`valloader` pair contains 4500 training examples and 500 validation examples. There's also a single `testloader` (we did not split the test set). Again, this is only necessary for building research or educational systems, actual federated learning systems have their data naturally distributed across multiple partitions.
#
# Let's take a look at the first batch of images and labels in the first training set (i.e., `trainloaders[0]`) before we move on:

# %%
images, labels = next(iter(trainloaders[0]))

# Reshape and convert images to a NumPy array
# matplotlib requires images with the shape (height, width, 3)
images = images.permute(0, 2, 3, 1).numpy()
# Denormalize
images = images / 2 + 0.5

# Create a figure and a grid of subplots
fig, axs = plt.subplots(4, 8, figsize=(12, 6))

# Loop over the images and plot them
for i, ax in enumerate(axs.flat):
    ax.imshow(images[i])
    ax.set_title(CLASSES[labels[i]])
    ax.axis("off")

# Show the plot
fig.tight_layout()
plt.show()

# %% [markdown]
# The output above shows a random batch of images from the first `trainloader` in our list of ten `trainloaders`. It also prints the labels associated with each image (i.e., one of the ten possible labels we've seen above). If you run the cell again, you should see another batch of images.

# %% [markdown]
# ## Step 1: Centralized Training with PyTorch

# %% [markdown]
# ![CentralizedTrain.png](data:image/png;base64,...)

# %% [markdown]
# Figure 1. Illustration of Centralized Training Architecture. (Source: Tim's Drawing)

# %% [markdown]
# Next, we're going to use PyTorch to define a simple convolutional neural network. This introduction assumes basic familiarity with PyTorch, so it doesn't cover the PyTorch-related aspects in full detail. If you want to dive deeper into PyTorch, please go into this page [*DEEP LEARNING WITH PYTORCH*](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html).

# %% [markdown]
# ### Defining the model
#
# We use the simple CNN described in the [PyTorch tutorial](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#define-a-convolutional-neural-network):

# %%
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ### Training the model
#
# We now have all the basic building blocks we need: a dataset, a model, a training function, and a test function. Let's put them together to train the model on the dataset of one of our organizations (`trainloaders[0]`). This simulates the reality of most machine learning projects today: each organization has their own data and trains models only on this internal data:

# %%
def train(net, trainloader, epochs: int, verbose=False):
    """Train the network on the training set."""
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters())
    net.train()
    for epoch in range(epochs):
        correct, total, epoch_loss = 0, 0, 0.0
        for images, labels in trainloader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = net(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            # Metrics
            epoch_loss += loss
            total += labels.size(0)
            correct += (torch.max(outputs.data, 1)[1] == labels).sum().item()
        epoch_loss /= len(trainloader.dataset)
        epoch_acc = correct / total
        if verbose:
            print(f"Epoch {epoch+1}: train loss {epoch_loss}, accuracy {epoch_acc}")


def test(net, testloader):
    """Evaluate the network on the entire test set."""
    criterion = torch.nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0.0
    net.eval()
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = net(images)
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    loss /= len(testloader.dataset)
    accuracy = correct / total
    return loss, accuracy



def plot_training_history(train_acc, val_acc, train_loss, val_loss):
    plt.figure(figsize=(12, 5))

    # Plot Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(train_acc, label='Training Accuracy', marker='o')
    plt.plot(val_acc, label='Validation Accuracy', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(train_loss, label='Training Loss', marker='o')
    plt.plot(val_loss, label='Validation Loss', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Training and Evaluation
trainloader = trainloaders[0]
valloader = valloaders[0]
net = Net().to(DEVICE)

train_acc_history = []
val_acc_history = []
train_loss_history = []
val_loss_history = []

for epoch in range(10):
    train(net, trainloader, 1)
    train_loss, train_accuracy = test(net, trainloader)
    val_loss, val_accuracy = test(net, valloader)

    train_acc_history.append(train_accuracy)
    val_acc_history.append(val_accuracy)
    train_loss_history.append(train_loss)
    val_loss_history.append(val_loss)

    print(f"Epoch {epoch+1}: validation loss {val_loss}, accuracy {val_accuracy}")

loss, accuracy = test(net, testloader)
print(f"Final test set performance:\n\tloss {loss}\n\taccuracy {accuracy}")

# Plot the training and validation history
plot_training_history(train_acc_history, val_acc_history, train_loss_history, val_loss_history)
# Out:
# Epoch 1: validation loss 0.06173406791687012, accuracy 0.284
# Epoch 2: validation loss 0.05663079738616943, accuracy 0.338
# Epoch 3: validation loss 0.05551257395744324, accuracy 0.334
# Epoch 4: validation loss 0.05408086585998535, accuracy 0.38
# Epoch 5: validation loss 0.052105417490005496, accuracy 0.422
# Epoch 6: validation loss 0.05083491516113281, accuracy 0.426
# Epoch 7: validation loss 0.04999161791801453, accuracy 0.428
# Epoch 8: validation loss 0.05127717995643616, accuracy 0.454
# Epoch 9: validation loss 0.04806605553627014, accuracy 0.468
# Epoch 10: validation loss 0.04978295922279358, accuracy 0.462
# Final test set performance:
# 	loss 0.047321669512987136
# 	accuracy 0.466

# %% [markdown]
# Training the simple CNN on our CIFAR-10 split for 5 epochs should result in a test set accuracy of about 41%, which is not good, but at the same time, it doesn't really matter for the purposes of this tutorial. The intent was just to show a simplistic centralized training pipeline that sets the stage for what comes next - federated learning!

# %% [markdown]
# ## Step 2: Federated Learning (using Flower)
#
# Step 1 demonstrated a simple centralized training pipeline. All data was in one place (i.e., a single `trainloader` and a single `valloader`). Next, we'll simulate a situation where we have multiple datasets in multiple organizations and where we train a model over these organizations using federated learning.

# %% [markdown]
# ![Federated_Main.png](data:image/png;base64,...)

# %% [markdown]
# Figure 2. Illustration of Distributed Training Architecture / Federated Learning. (Source: Tim's Drawing)

# %% [markdown]
# ### Updating model parameters
#
# In federated learning, the server sends the global model parameters to the client, and the client updates the local model with the parameters received from the server. It then trains the model on the local data (which changes the model parameters locally) and sends the updated/changed model parameters back to the server (or, alternatively, it sends just the gradients back to the server, not the full model parameters).
#
# We need two helper functions to update the local model with parameters received from the server and to get the updated model parameters from the local model: `set_parameters` and `get_parameters`. The following two functions do just that for the PyTorch model above.
#
# The details of how this works are not really important here (feel free to consult the PyTorch documentation if you want to learn more). In essence, we use `state_dict` to access PyTorch model parameter tensors. The parameter tensors are then converted to/from a list of NumPy ndarray's (which Flower knows how to serialize/deserialize):

# %%
def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]


def set_parameters(net, parameters: List[np.ndarray]):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)

# %% [markdown]
# ### Implementing a Flower client
#
# With that out of the way, let's move on to the interesting part. Federated learning systems consist of a server and multiple clients. In Flower, we create clients by implementing subclasses of `flwr.client.Client` or `flwr.client.NumPyClient`. We use `NumPyClient` in this tutorial because it is easier to implement and requires us to write less boilerplate.
#
# To implement the Flower client, we create a subclass of `flwr.client.NumPyClient` and implement the three methods `get_parameters`, `fit`, and `evaluate`:
#
# * `get_parameters`: Return the current local model parameters
# * `fit`: Receive model parameters from the server, train the model parameters on the local data, and return the (updated) model parameters to the server
# * `evaluate`: Receive model parameters from the server, evaluate the model parameters on the local data, and return the evaluation result to the server
#
# We mentioned that our clients will use the previously defined PyTorch components for model training and evaluation. Let's see a simple Flower client implementation that brings everything together:

# %%
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, net, trainloader, valloader):
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader

    def get_parameters(self, config):
        return get_parameters(self.net)

    def fit(self, parameters, config):
        set_parameters(self.net, parameters)
        train(self.net, self.trainloader, epochs=1)
        return get_parameters(self.net), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        set_parameters(self.net, parameters)
        loss, accuracy = test(self.net, self.valloader)
        return float(loss), len(self.valloader), {"accuracy": float(accuracy)}

# %% [markdown]
# Our class `FlowerClient` defines how local training/evaluation will be performed and allows Flower to call the local training/evaluation through `fit` and `evaluate`. Each instance of `FlowerClient` represents a *single client* in our federated learning system. Federated learning systems have multiple clients (otherwise, there's not much to federate), so each client will be represented by its own instance of `FlowerClient`. If we have, for example, three clients in our workload, then we'd have three instances of `FlowerClient`. Flower calls `FlowerClient.fit` on the respective instance when the server selects a particular client for training (and `FlowerClient.evaluate` for evaluation).
#
# ### Using the Virtual Client Engine
#
# In this notebook, we want to simulate a federated learning system with 10 clients on a single machine. This means that the server and all 10 clients will live on a single machine and share resources such as CPU, GPU, and memory. Having 10 clients would mean having 10 instances of `FlowerClient` in memory. Doing this on a single machine can quickly exhaust the available memory resources, even if only a subset of these clients participates in a single round of federated learning.
#
# In addition to the regular capabilities where server and clients run on multiple machines, Flower, therefore, provides special simulation capabilities that create `FlowerClient` instances only when they are actually necessary for training or evaluation. To enable the Flower framework to create clients when necessary, we need to implement a function called `client_fn` that creates a `FlowerClient` instance on demand. Flower calls `client_fn` whenever it needs an instance of one particular client to call `fit` or `evaluate` (those instances are usually discarded after use, so they should not keep any local state). Clients are identified by a client ID, or short `cid`. The `cid` can be used, for example, to load different local data partitions for different clients, as can be seen below:

# %%
def client_fn(cid: str) -> FlowerClient:
    """Create a Flower client representing a single organization."""

    # Load model
    net = Net().to(DEVICE)

    # Load data (CIFAR-10)
    # Note: each client gets a different trainloader/valloader, so each client
    # will train and evaluate on their own unique data
    trainloader = trainloaders[int(cid)]
    valloader = valloaders[int(cid)]

    # Create a  single Flower client representing a single organization
    return FlowerClient(net, trainloader, valloader)

# %% [markdown]
# ### Starting the training
#
# We now have the class `FlowerClient` which defines client-side training/evaluation and `client_fn` which allows Flower to create `FlowerClient` instances whenever it needs to call `fit` or `evaluate` on one particular client. The last step is to start the actual simulation using `flwr.simulation.start_simulation`.
#
# The function `start_simulation` accepts a number of arguments, amongst them the `client_fn` used to create `FlowerClient` instances, the number of clients to simulate (`num_clients`), the number of federated learning rounds (`num_rounds`), and the strategy. The strategy encapsulates the federated learning approach/algorithm, for example, *Federated Averaging* (FedAvg).
#
# Flower has a number of built-in strategies, but we can also use our own strategy implementations to customize nearly all aspects of the federated learning approach. For this example, we use the built-in `FedAvg` implementation and customize it using a few basic parameters. The last step is the actual call to `start_simulation` which - you guessed it - starts the simulation:

# %%
#Define whether you are going to use GPU or CPU (it opts CPU by default)
client_resources = None
if DEVICE.type == "cuda":
    client_resources = {"num_gpus": 1}

# %% [markdown]
# ### Behind the scenes
#
# So how does this work? How does Flower execute this simulation?
#
# When we call `start_simulation`, we tell Flower that there are 10 clients (`num_clients=10`). Flower then goes ahead an asks the `FedAvg` strategy to select clients. `FedAvg` knows that it should select 100% of the available clients (`fraction_fit=1.0`), so it goes ahead and selects 10 random clients (i.e., 100% of 10).
#
# Flower then asks the selected 10 clients to train the model. When the server receives the model parameter updates from the clients, it hands those updates over to the strategy (*FedAvg*) for aggregation. The strategy aggregates those updates and returns the new global model, which then gets used in the next round of federated learning.

# %% [markdown]
# ### Where's the accuracy?
#
# You may have noticed that all metrics except for `losses_distributed` are empty. Where did the `{"accuracy": float(accuracy)}` go?
#
# Flower can automatically aggregate losses returned by individual clients, but it cannot do the same for metrics in the generic metrics dictionary (the one with the `accuracy` key). Metrics dictionaries can contain very different kinds of metrics and even key/value pairs that are not metrics at all, so the framework does not (and can not) know how to handle these automatically.
#
# As users, we need to tell the framework how to handle/aggregate these custom metrics, and we do so by passing metric aggregation functions to the strategy. The strategy will then call these functions whenever it receives fit or evaluate metrics from clients. The two possible functions are `fit_metrics_aggregation_fn` and `evaluate_metrics_aggregation_fn`.
#
# Let's create a simple weighted averaging function to aggregate the `accuracy` metric we return from `evaluate`:

# %%
def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    # Multiply accuracy of each client by number of examples used
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]

    # Aggregate and return custom metric (weighted average)
    return {"accuracy": sum(accuracies) / sum(examples)}

# %% [markdown]
# The only thing left to do is to tell the strategy to call this function whenever it receives evaluation metric dictionaries from the clients:

# %%
# Create FedAvg strategy
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,
    fraction_evaluate=0.5,
    min_fit_clients=10,
    min_evaluate_clients=5,
    min_available_clients=5,
    evaluate_metrics_aggregation_fn=weighted_average,  # <-- pass the metric aggregation function
)

# Start simulation
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=5),
    strategy=strategy,
    client_resources=client_resources,
)
# Out:
# WARNING flwr 2023-11-08 08:41:46,609 | fedavg.py:117 |
# Setting `min_available_clients` lower than `min_fit_clients` or
# `min_evaluate_clients` can cause the server to fail when there are too few clients
# connected to the server. `min_available_clients` must be set to a value larger
# than or equal to the values of `min_fit_clients` and `min_evaluate_clients`.
#
# WARNING:flwr:
# Setting `min_available_clients` lower than `min_fit_clients` or
# `min_evaluate_clients` can cause the server to fail when there are too few clients
# connected to the server. `min_available_clients` must be set to a value larger
# than or equal to the values of `min_fit_clients` and `min_evaluate_clients`.
#
# INFO flwr 2023-11-08 08:41:46,613 | app.py:175 | Starting Flower simulation, config: ServerConfig(num_rounds=5, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=5, round_timeout=None)
# 2023-11-08 08:41:50,842	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2023-11-08 08:41:52,993 | app.py:210 | Flower VCE: Ray initialized with resources: {'object_store_memory': 3911858995.0, 'memory': 7823717991.0, 'node:__internal_head__': 1.0, 'CPU': 2.0, 'node:172.28.0.12': 1.0, 'GPU': 1.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'object_store_memory': 3911858995.0, 'memory': 7823717991.0, 'node:__internal_head__': 1.0, 'CPU': 2.0, 'node:172.28.0.12': 1.0, 'GPU': 1.0}
# INFO flwr 2023-11-08 08:41:52,998 | app.py:218 | No `client_resources` specified. Using minimal resources for clients.
# INFO:flwr:No `client_resources` specified. Using minimal resources for clients.
# INFO flwr 2023-11-08 08:41:53,001 | app.py:224 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO:flwr:Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO flwr 2023-11-08 08:41:53,050 | app.py:270 | Flower VCE: Creating VirtualClientEngineActorPool with 2 actors
# INFO:flwr:Flower VCE: Creating VirtualClientEngineActorPool with 2 actors
# INFO flwr 2023-11-08 08:41:53,058 | server.py:89 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2023-11-08 08:41:53,064 | server.py:276 | Requesting initial parameters from one random client
# INFO:flwr:Requesting initial parameters from one random client
# (pid=15788) 2023-11-08 08:41:56.296773: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=15788) 2023-11-08 08:41:56.296839: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=15788) 2023-11-08 08:41:56.296876: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=15788) 2023-11-08 08:41:58.064477: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO flwr 2023-11-08 08:42:05,030 | server.py:280 | Received initial parameters from one random client
# INFO:flwr:Received initial parameters from one random client
# INFO flwr 2023-11-08 08:42:05,036 | server.py:91 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2023-11-08 08:42:05,040 | server.py:104 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2023-11-08 08:42:05,044 | server.py:222 | fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-11-08 08:42:43,052 | server.py:236 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# WARNING flwr 2023-11-08 08:42:43,082 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# WARNING:flwr:No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-11-08 08:42:43,085 | server.py:173 | evaluate_round 1: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 1: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-11-08 08:42:52,915 | server.py:187 | evaluate_round 1 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 1 received 5 results and 0 failures
# DEBUG flwr 2023-11-08 08:42:52,919 | server.py:222 | fit_round 2: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-11-08 08:43:29,952 | server.py:236 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# DEBUG flwr 2023-11-08 08:43:29,982 | server.py:173 | evaluate_round 2: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 2: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-11-08 08:43:37,777 | server.py:187 | evaluate_round 2 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 2 received 5 results and 0 failures
# DEBUG flwr 2023-11-08 08:43:37,780 | server.py:222 | fit_round 3: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-11-08 08:44:19,003 | server.py:236 | fit_round 3 received 10 results and 0 failures
# DEBUG:flwr:fit_round 3 received 10 results and 0 failures
# DEBUG flwr 2023-11-08 08:44:19,034 | server.py:173 | evaluate_round 3: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 3: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-11-08 08:44:26,837 | server.py:187 | evaluate_round 3 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 3 received 5 results and 0 failures
# DEBUG flwr 2023-11-08 08:44:26,840 | server.py:222 | fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-11-08 08:45:05,281 | server.py:236 | fit_round 4 received 10 results and 0 failures
# DEBUG:flwr:fit_round 4 received 10 results and 0 failures
# DEBUG flwr 2023-11-08 08:45:05,306 | server.py:173 | evaluate_round 4: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 4: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-11-08 08:45:13,000 | server.py:187 | evaluate_round 4 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 4 received 5 results and 0 failures
# DEBUG flwr 2023-11-08 08:45:13,004 | server.py:222 | fit_round 5: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 5: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-11-08 08:45:49,119 | server.py:236 | fit_round 5 received 10 results and 0 failures
# DEBUG:flwr:fit_round 5 received 10 results and 0 failures
# DEBUG flwr 2023-11-08 08:45:49,154 | server.py:173 | evaluate_round 5: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 5: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-11-08 08:45:58,555 | server.py:187 | evaluate_round 5 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 5 received 5 results and 0 failures
# INFO flwr 2023-11-08 08:45:58,562 | server.py:153 | FL finished in 233.51851595800008
# INFO:flwr:FL finished in 233.51851595800008
# INFO flwr 2023-11-08 08:45:58,567 | app.py:225 | app_fit: losses_distributed [(1, 0.06291721167564393), (2, 0.054808236885070805), (3, 0.05118304071426392), (4, 0.049559094667434696), (5, 0.04759830298423767)]
# INFO:flwr:app_fit: losses_distributed [(1, 0.06291721167564393), (2, 0.054808236885070805), (3, 0.05118304071426392), (4, 0.049559094667434696), (5, 0.04759830298423767)]
# INFO flwr 2023-11-08 08:45:58,571 | app.py:226 | app_fit: metrics_distributed_fit {}
# INFO:flwr:app_fit: metrics_distributed_fit {}
# INFO flwr 2023-11-08 08:45:58,573 | app.py:227 | app_fit: metrics_distributed {'accuracy': [(1, 0.2676), (2, 0.36760000000000004), (3, 0.39999999999999997), (4, 0.4288), (5, 0.4524)]}
# INFO:flwr:app_fit: metrics_distributed {'accuracy': [(1, 0.2676), (2, 0.36760000000000004), (3, 0.39999999999999997), (4, 0.4288), (5, 0.4524)]}
# INFO flwr 2023-11-08 08:45:58,576 | app.py:228 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2023-11-08 08:45:58,579 | app.py:229 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 0.06291721167564393
# 	round 2: 0.054808236885070805
# 	round 3: 0.05118304071426392
# 	round 4: 0.049559094667434696
# 	round 5: 0.04759830298423767
# History (metrics, distributed, evaluate):
# {'accuracy': [(1, 0.2676), (2, 0.36760000000000004), (3, 0.39999999999999997), (4, 0.4288), (5, 0.4524)]}

# %% [markdown]
# We now have a full system that performs federated training and federated evaluation. It uses the `weighted_average` function to aggregate custom evaluation metrics and calculates a single `accuracy` metric across all clients on the server side.
#
# The other two categories of metrics (`losses_centralized` and `metrics_centralized`) are still empty because they only apply when centralized evaluation is being used. Part two of the Flower tutorial will cover centralized evaluation.

# %%
def plot_training_history(train_acc, val_acc, train_loss, val_loss, num_clients):
    plt.figure(figsize=(12, 5))

    # Plot Accuracy
    plt.subplot(1, 2, 1)
    for i in range(num_clients):
        plt.plot(train_acc[i], label=f'Client {i} Training Accuracy', marker='o')
        plt.plot(val_acc[i], label=f'Client {i} Validation Accuracy', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    # Plot Loss
    plt.subplot(1, 2, 2)
    for i in range(num_clients):
        plt.plot(train_loss[i], label=f'Client {i} Training Loss', marker='o')
        plt.plot(val_loss[i], label=f'Client {i} Validation Loss', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Training and Evaluation
train_acc_history = []
val_acc_history = []
train_loss_history = []
val_loss_history = []

for client_id in range(NUM_CLIENTS):
    trainloader = trainloaders[client_id]
    valloader = valloaders[client_id]
    net = Net().to(DEVICE)

    train_acc_client = []
    val_acc_client = []
    train_loss_client = []
    val_loss_client = []

    for epoch in range(10):
        train(net, trainloader, 1)
        train_loss, train_accuracy = test(net, trainloader)
        val_loss, val_accuracy = test(net, valloader)

        train_acc_client.append(train_accuracy)
        val_acc_client.append(val_accuracy)
        train_loss_client.append(train_loss)
        val_loss_client.append(val_loss)

        print(f"Client {client_id}, Epoch {epoch+1}: validation loss {val_loss}, accuracy {val_accuracy}")

    train_acc_history.append(train_acc_client)
    val_acc_history.append(val_acc_client)
    train_loss_history.append(train_loss_client)
    val_loss_history.append(val_loss_client)

# Plot the training and validation history for all clients
num_clients = NUM_CLIENTS
plot_training_history(train_acc_history, val_acc_history, train_loss_history, val_loss_history, num_clients)

# Create FedAvg strategy
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,
    fraction_evaluate=0.5,
    min_fit_clients=10,
    min_evaluate_clients=5,
    min_available_clients=5,
    evaluate_metrics_aggregation_fn=weighted_average,  # <-- pass the metric aggregation function
)

# Start simulation
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=5),
    strategy=strategy,
    client_resources=client_resources,
)
# Out:
# Client 0, Epoch 1: validation loss 0.06196862363815308, accuracy 0.254
# Client 0, Epoch 2: validation loss 0.056786542892456056, accuracy 0.35
# Client 0, Epoch 3: validation loss 0.053720951080322266, accuracy 0.378
# Client 0, Epoch 4: validation loss 0.056054609060287475, accuracy 0.344
# Client 0, Epoch 5: validation loss 0.05276424264907837, accuracy 0.398
# Client 0, Epoch 6: validation loss 0.0528083484172821, accuracy 0.426
# Client 0, Epoch 7: validation loss 0.05064230990409851, accuracy 0.434
# Client 0, Epoch 8: validation loss 0.04972577738761902, accuracy 0.446
# Client 0, Epoch 9: validation loss 0.049886311531066894, accuracy 0.46
# Client 0, Epoch 10: validation loss 0.05107067584991455, accuracy 0.444
# Client 1, Epoch 1: validation loss 0.06031570649147034, accuracy 0.32
# Client 1, Epoch 2: validation loss 0.055843823432922365, accuracy 0.366
# Client 1, Epoch 3: validation loss 0.052706892013549805, accuracy 0.404
# Client 1, Epoch 4: validation loss 0.05009477829933166, accuracy 0.444
# Client 1, Epoch 5: validation loss 0.04973243618011475, accuracy 0.41
# Client 1, Epoch 6: validation loss 0.04737325549125671, accuracy 0.464
# Client 1, Epoch 7: validation loss 0.04904635810852051, accuracy 0.42
# Client 1, Epoch 8: validation loss 0.04696981883049011, accuracy 0.452
# Client 1, Epoch 9: validation loss 0.04955103039741516, accuracy 0.412
# Client 1, Epoch 10: validation loss 0.046638330698013306, accuracy 0.468
# Client 2, Epoch 1: validation loss 0.059921362161636356, accuracy 0.306
# Client 2, Epoch 2: validation loss 0.054944138288497923, accuracy 0.372
# Client 2, Epoch 3: validation loss 0.055103929996490476, accuracy 0.37
# Client 2, Epoch 4: validation loss 0.052464221477508545, accuracy 0.392
# Client 2, Epoch 5: validation loss 0.050553308963775634, accuracy 0.392
# Client 2, Epoch 6: validation loss 0.05126646304130554, accuracy 0.454
# Client 2, Epoch 7: validation loss 0.05007519316673279, accuracy 0.428
# Client 2, Epoch 8: validation loss 0.05066417264938355, accuracy 0.426
# Client 2, Epoch 9: validation loss 0.04927227163314819, accuracy 0.462
# Client 2, Epoch 10: validation loss 0.04981247735023499, accuracy 0.448
# Client 3, Epoch 1: validation loss 0.06135667061805725, accuracy 0.314
# Client 3, Epoch 2: validation loss 0.05629622888565063, accuracy 0.348
# Client 3, Epoch 3: validation loss 0.05228086853027344, accuracy 0.384
# Client 3, Epoch 4: validation loss 0.05143168830871582, accuracy 0.4
# Client 3, Epoch 5: validation loss 0.047876404762268066, accuracy 0.454
# Client 3, Epoch 6: validation loss 0.047994678258895876, accuracy 0.43
# Client 3, Epoch 7: validation loss 0.048913932085037234, accuracy 0.446
# Client 3, Epoch 8: validation loss 0.04661425566673279, accuracy 0.474
# Client 3, Epoch 9: validation loss 0.0463116147518158, accuracy 0.484
# Client 3, Epoch 10: validation loss 0.04726867055892944, accuracy 0.474
# Client 4, Epoch 1: validation loss 0.061428818464279174, accuracy 0.27
# Client 4, Epoch 2: validation loss 0.055740458726882935, accuracy 0.334
# Client 4, Epoch 3: validation loss 0.053923053741455076, accuracy 0.364
# Client 4, Epoch 4: validation loss 0.051994707822799684, accuracy 0.392
# Client 4, Epoch 5: validation loss 0.05112811422348022, accuracy 0.412
# Client 4, Epoch 6: validation loss 0.052739667654037474, accuracy 0.382
# Client 4, Epoch 7: validation loss 0.04995512199401855, accuracy 0.404
# Client 4, Epoch 8: validation loss 0.05000347566604614, accuracy 0.414
# Client 4, Epoch 9: validation loss 0.049519945859909056, accuracy 0.41
# Client 4, Epoch 10: validation loss 0.04882052183151245, accuracy 0.44
# Client 5, Epoch 1: validation loss 0.06062328672409058, accuracy 0.336
# Client 5, Epoch 2: validation loss 0.053093583822250365, accuracy 0.38
# Client 5, Epoch 3: validation loss 0.05188728094100952, accuracy 0.4
# Client 5, Epoch 4: validation loss 0.04989886069297791, accuracy 0.414
# Client 5, Epoch 5: validation loss 0.04728037905693054, accuracy 0.452
# Client 5, Epoch 6: validation loss 0.04655824065208435, accuracy 0.458
# Client 5, Epoch 7: validation loss 0.04517596817016602, accuracy 0.486
# Client 5, Epoch 8: validation loss 0.04463337230682373, accuracy 0.46
# Client 5, Epoch 9: validation loss 0.043267908334732055, accuracy 0.506
# Client 5, Epoch 10: validation loss 0.044320499181747436, accuracy 0.492
# Client 6, Epoch 1: validation loss 0.060583637714385984, accuracy 0.308
# Client 6, Epoch 2: validation loss 0.05747148847579956, accuracy 0.348
# Client 6, Epoch 3: validation loss 0.05331697154045105, accuracy 0.398
# Client 6, Epoch 4: validation loss 0.052244645833969115, accuracy 0.422
# Client 6, Epoch 5: validation loss 0.05025532054901123, accuracy 0.444
# Client 6, Epoch 6: validation loss 0.05070522046089172, accuracy 0.424
# Client 6, Epoch 7: validation loss 0.049518635272979734, accuracy 0.446
# Client 6, Epoch 8: validation loss 0.04925148320198059, accuracy 0.432
# Client 6, Epoch 9: validation loss 0.05044853258132934, accuracy 0.436
# Client 6, Epoch 10: validation loss 0.05082472729682922, accuracy 0.446
# Client 7, Epoch 1: validation loss 0.06131355500221253, accuracy 0.278
# Client 7, Epoch 2: validation loss 0.05689865159988403, accuracy 0.328
# Client 7, Epoch 3: validation loss 0.054275261402130126, accuracy 0.38
# Client 7, Epoch 4: validation loss 0.0539586820602417, accuracy 0.376
# Client 7, Epoch 5: validation loss 0.05210924077033997, accuracy 0.402
# Client 7, Epoch 6: validation loss 0.050492621660232544, accuracy 0.408
# Client 7, Epoch 7: validation loss 0.049695365190505984, accuracy 0.432
# Client 7, Epoch 8: validation loss 0.04944996190071106, accuracy 0.444
# Client 7, Epoch 9: validation loss 0.04789281415939331, accuracy 0.446
# Client 7, Epoch 10: validation loss 0.047888892650604246, accuracy 0.442
# Client 8, Epoch 1: validation loss 0.06089668345451355, accuracy 0.312
# Client 8, Epoch 2: validation loss 0.05471496820449829, accuracy 0.374
# Client 8, Epoch 3: validation loss 0.054044840812683105, accuracy 0.38
# Client 8, Epoch 4: validation loss 0.051278867959976195, accuracy 0.4
# Client 8, Epoch 5: validation loss 0.05005320167541504, accuracy 0.42
# Client 8, Epoch 6: validation loss 0.04860801386833191, accuracy 0.414
# Client 8, Epoch 7: validation loss 0.04761577033996582, accuracy 0.444
# Client 8, Epoch 8: validation loss 0.04839534378051758, accuracy 0.436
# Client 8, Epoch 9: validation loss 0.04883137011528015, accuracy 0.432
# Client 8, Epoch 10: validation loss 0.04825974321365357, accuracy 0.466
# Client 9, Epoch 1: validation loss 0.06303203296661376, accuracy 0.266
# Client 9, Epoch 2: validation loss 0.05778734469413757, accuracy 0.342
# Client 9, Epoch 3: validation loss 0.0552962555885315, accuracy 0.334
# Client 9, Epoch 4: validation loss 0.05272195339202881, accuracy 0.418
# Client 9, Epoch 5: validation loss 0.05134453463554382, accuracy 0.422
# Client 9, Epoch 6: validation loss 0.049584270000457766, accuracy 0.426
# Client 9, Epoch 7: validation loss 0.05021408224105835, accuracy 0.42
# Client 9, Epoch 8: validation loss 0.04859928131103516, accuracy 0.468
# Client 9, Epoch 9: validation loss 0.049904245734214786, accuracy 0.442
# Client 9, Epoch 10: validation loss 0.050481961488723755, accuracy 0.448
# WARNING flwr 2023-11-08 09:23:14,608 | fedavg.py:117 |
# Setting `min_available_clients` lower than `min_fit_clients` or
# `min_evaluate_clients` can cause the server to fail when there are too few clients
# connected to the server. `min_available_clients` must be set to a value larger
# than or equal to the values of `min_fit_clients` and `min_evaluate_clients`.
#
# WARNING:flwr:
# Setting `min_available_clients` lower than `min_fit_clients` or
# `min_evaluate_clients` can cause the server to fail when there are too few clients
# connected to the server. `min_available_clients` must be set to a value larger
# than or equal to the values of `min_fit_clients` and `min_evaluate_clients`.
#
# INFO flwr 2023-11-08 09:23:14,613 | app.py:175 | Starting Flower simulation, config: ServerConfig(num_rounds=5, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=5, round_timeout=None)
# 2023-11-08 09:23:18,535	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2023-11-08 09:23:20,993 | app.py:210 | Flower VCE: Ray initialized with resources: {'memory': 7834627278.0, 'node:172.28.0.12': 1.0, 'GPU': 1.0, 'object_store_memory': 3917313638.0, 'node:__internal_head__': 1.0, 'CPU': 2.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'memory': 7834627278.0, 'node:172.28.0.12': 1.0, 'GPU': 1.0, 'object_store_memory': 3917313638.0, 'node:__internal_head__': 1.0, 'CPU': 2.0}
# INFO flwr 2023-11-08 09:23:21,006 | app.py:218 | No `client_resources` specified. Using minimal resources for clients.
# INFO:flwr:No `client_resources` specified. Using minimal resources for clients.
# INFO flwr 2023-11-08 09:23:21,009 | app.py:224 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO:flwr:Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO flwr 2023-11-08 09:23:21,065 | app.py:270 | Flower VCE: Creating VirtualClientEngineActorPool with 2 actors
# INFO:flwr:Flower VCE: Creating VirtualClientEngineActorPool with 2 actors
# INFO flwr 2023-11-08 09:23:21,068 | server.py:89 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2023-11-08 09:23:21,070 | server.py:276 | Requesting initial parameters from one random client
# INFO:flwr:Requesting initial parameters from one random client
# (pid=26807) 2023-11-08 09:23:24.361253: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=26807) 2023-11-08 09:23:24.361312: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=26807) 2023-11-08 09:23:24.361350: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=26807) 2023-11-08 09:23:26.169014: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO flwr 2023-11-08 09:23:32,132 | server.py:280 | Received initial parameters from one random client
# INFO:flwr:Received initial parameters from one random client
# INFO flwr 2023-11-08 09:23:32,138 | server.py:91 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2023-11-08 09:23:32,140 | server.py:104 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2023-11-08 09:23:32,144 | server.py:222 | fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-11-08 09:24:11,886 | server.py:236 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# WARNING flwr 2023-11-08 09:24:11,916 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# WARNING:flwr:No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-11-08 09:24:11,919 | server.py:173 | evaluate_round 1: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 1: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-11-08 09:24:20,740 | server.py:187 | evaluate_round 1 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 1 received 5 results and 0 failures
# DEBUG flwr 2023-11-08 09:24:20,746 | server.py:222 | fit_round 2: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-11-08 09:24:57,421 | server.py:236 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# DEBUG flwr 2023-11-08 09:24:57,449 | server.py:173 | evaluate_round 2: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 2: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-11-08 09:25:05,133 | server.py:187 | evaluate_round 2 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 2 received 5 results and 0 failures
# DEBUG flwr 2023-11-08 09:25:05,137 | server.py:222 | fit_round 3: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-11-08 09:25:42,285 | server.py:236 | fit_round 3 received 10 results and 0 failures
# DEBUG:flwr:fit_round 3 received 10 results and 0 failures
# DEBUG flwr 2023-11-08 09:25:42,344 | server.py:173 | evaluate_round 3: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 3: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-11-08 09:25:50,819 | server.py:187 | evaluate_round 3 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 3 received 5 results and 0 failures
# DEBUG flwr 2023-11-08 09:25:50,825 | server.py:222 | fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-11-08 09:26:26,358 | server.py:236 | fit_round 4 received 10 results and 0 failures
# DEBUG:flwr:fit_round 4 received 10 results and 0 failures
# DEBUG flwr 2023-11-08 09:26:26,386 | server.py:173 | evaluate_round 4: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 4: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-11-08 09:26:36,497 | server.py:187 | evaluate_round 4 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 4 received 5 results and 0 failures
# DEBUG flwr 2023-11-08 09:26:36,502 | server.py:222 | fit_round 5: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 5: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-11-08 09:27:13,563 | server.py:236 | fit_round 5 received 10 results and 0 failures
# DEBUG:flwr:fit_round 5 received 10 results and 0 failures
# DEBUG flwr 2023-11-08 09:27:13,593 | server.py:173 | evaluate_round 5: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 5: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-11-08 09:27:23,916 | server.py:187 | evaluate_round 5 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 5 received 5 results and 0 failures
# INFO flwr 2023-11-08 09:27:23,925 | server.py:153 | FL finished in 231.78117220999957
# INFO:flwr:FL finished in 231.78117220999957
# INFO flwr 2023-11-08 09:27:23,933 | app.py:225 | app_fit: losses_distributed [(1, 0.06288479390144348), (2, 0.05509691247940064), (3, 0.051312111568450926), (4, 0.05057554206848144), (5, 0.04751960506439209)]
# INFO:flwr:app_fit: losses_distributed [(1, 0.06288479390144348), (2, 0.05509691247940064), (3, 0.051312111568450926), (4, 0.05057554206848144), (5, 0.04751960506439209)]
# INFO flwr 2023-11-08 09:27:23,936 | app.py:226 | app_fit: metrics_distributed_fit {}
# INFO:flwr:app_fit: metrics_distributed_fit {}
# INFO flwr 2023-11-08 09:27:23,938 | app.py:227 | app_fit: metrics_distributed {'accuracy': [(1, 0.278), (2, 0.35839999999999994), (3, 0.4152), (4, 0.41320000000000007), (5, 0.45360000000000006)]}
# INFO:flwr:app_fit: metrics_distributed {'accuracy': [(1, 0.278), (2, 0.35839999999999994), (3, 0.4152), (4, 0.41320000000000007), (5, 0.45360000000000006)]}
# INFO flwr 2023-11-08 09:27:23,941 | app.py:228 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2023-11-08 09:27:23,950 | app.py:229 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 0.06288479390144348
# 	round 2: 0.05509691247940064
# 	round 3: 0.051312111568450926
# 	round 4: 0.05057554206848144
# 	round 5: 0.04751960506439209
# History (metrics, distributed, evaluate):
# {'accuracy': [(1, 0.278), (2, 0.35839999999999994), (3, 0.4152), (4, 0.41320000000000007), (5, 0.45360000000000006)]}

# %% [markdown]
# ## Conclusions
#
#
# Through this simulation, you've learned about:
# *   Federated Learning principles running from 10 clients (or more)
# *   The basic concept of Centralized Training vs. Federated Training
# *   Utilizing available open datasets (CIFAR10)
# *   Centralized Training: Trained on single entity
# *   Federated Training: Trained on multiple entities defined as "Client" and Aggregator as "Server"
#
#
#
#
# ## Future Works
# *   Many other test-beds can be explored (TFF,FedML)
# *   You could customize your own FL for certain applications or scenarios
